# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models
batch_size = 32
epochs = 1

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
train_transforms = transforms.Compose([transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],
                                                            [0.229, 0.224, 0.225])])

valid_transforms = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],
                                                           [0.229, 0.224, 0.225])])

test_transforms = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],
                                                           [0.229, 0.224, 0.225])])

# Pass transforms in here, then run the next cell to see how the transforms look
train_data = datasets.ImageFolder(data_dir + '/train', transform=train_transforms)
valid_data = datasets.ImageFolder(data_dir + '/valid', transform=valid_transforms)
test_data = datasets.ImageFolder(data_dir + '/test', transform=test_transforms)

trainloader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
validloader = torch.utils.data.DataLoader(valid_data, batch_size=batch_size)
testloader = torch.utils.data.DataLoader(test_data, batch_size=batch_size)

# %%
#train_data
class_to_idx = train_data.class_to_idx
idx_to_class = dict([[v,k] for k,v in class_to_idx.items()])

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)
    
num_classes = len(cat_to_name.keys())
print('number of categories: {}'.format(num_classes))
# Out:
# number of categories: 102

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. If you want to talk through it with someone, chat with your fellow students! You can also ask questions on the forums or join the instructors in office hours.
#
# Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.

# %%
# Use GPU if it's available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# load pre-trained model
model = models.vgg16(pretrained=True)
model.name = 'vgg16'
print(model.name)
# Out:
# vgg16

# %% [markdown]
# Notes:  Changed Dropout from p=0.2 to 0.1

# %%
# Freeze parameters so we don't backprop through them
for param in model.parameters():
    param.requires_grad = False

from collections import OrderedDict
classifier_dict = OrderedDict([
                           ('fc1', nn.Linear(25088, 4096, bias=True)),
                           ('relu', nn.ReLU()),
                           ('do1', nn.Dropout(p=0.1)),
                           ('fc2', nn.Linear(4096, 102, bias=True)),
                           ('output', nn.LogSoftmax(dim=1))
                           ])

model.classifier = nn.Sequential(classifier_dict)
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=0.003)

# load model into gpu
model.to(device);

# %%
def validate_nn(loader, model):
    test_loss = 0
    accuracy = 0
    model.eval()
    steps = 0
    with torch.no_grad():
        for inputs, labels in loader:
            steps += 1
            inputs, labels = inputs.to(device), labels.to(device)
            logps = model.forward(inputs)
            batch_loss = criterion(logps, labels)

            test_loss += batch_loss.item()

            # Calculate accuracy
            ps = torch.exp(logps)
            top_p, top_class = ps.topk(1, dim=1)
            equals = top_class == labels.view(*top_class.shape)
            accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

        model.train()
        return test_loss, accuracy

# %%
import gc
import sys
import psutil
import os
def memReport():
    for obj in gc.get_objects():
        if torch.is_tensor(obj):
            print(type(obj), obj.size())
    
def cpuStats():
        print(sys.version)
        print(psutil.cpu_percent())
        print(psutil.virtual_memory())  # physical memory usage
        pid = os.getpid()
        py = psutil.Process(pid)
        memoryUse = py.memory_info()[0] / 2. ** 30  # memory use in GB...I think
        print('memory GB:', memoryUse)

# %%
def train_nn(model, epochs, criterion, optimizer, trainloader, validloader):
    running_loss = 0
    print_every = 5
    model.train()
    for epoch in range(epochs):
        #cpuStats()
        #memReport()
        steps = 0
        for inputs, labels in trainloader:
            torch.cuda.empty_cache() 
            steps += 1
            # Move input and label tensors to the default device
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()

            logps = model.forward(inputs)
            loss = criterion(logps, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            if steps % print_every == 0:

                valid_loss, accuracy = validate_nn(validloader, model)                    
                print(f"Step {steps}/{len(trainloader)}.. ",
                      f"Epoch {epoch+1}/{epochs}.. "
                      f"Train loss: {running_loss/print_every:.3f}.. "
                      f"Valid. loss: {valid_loss/len(validloader):.3f}.. "
                      f"Valid. accuracy: {accuracy/len(validloader):.3f}")

                running_loss = 0
                model.train()

# %%
torch.cuda.empty_cache() 
train_nn(model, epochs, criterion, optimizer, trainloader, validloader)
# Out:
# 3.6.6 |Anaconda, Inc.| (default, Jun 28 2018, 11:27:44) [MSC v.1900 64 bit (AMD64)]
# 16.7
# svmem(total=16978071552, available=9053491200, percent=46.7, used=7924580352, free=9053491200)
# memory GB: 1.1249465942382812
# <class 'torch.nn.parameter.Parameter'> torch.Size([64, 3, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64, 64, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128, 64, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128, 128, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 128, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 256, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1000])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 256, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 256, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([102])
# <class 'torch.nn.parameter.Parameter'> torch.Size([102, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 25088])
# Step 5/205..  Epoch 1/5.. Train loss: 47.054.. Valid. loss: 34.214.. Valid. accuracy: 0.050
# Step 10/205..  Epoch 1/5.. Train loss: 19.347.. Valid. loss: 5.587.. Valid. accuracy: 0.102
# Step 15/205..  Epoch 1/5.. Train loss: 4.884.. Valid. loss: 3.957.. Valid. accuracy: 0.163
# Step 20/205..  Epoch 1/5.. Train loss: 3.908.. Valid. loss: 3.952.. Valid. accuracy: 0.177
# Step 25/205..  Epoch 1/5.. Train loss: 3.875.. Valid. loss: 3.677.. Valid. accuracy: 0.267
# Step 30/205..  Epoch 1/5.. Train loss: 3.965.. Valid. loss: 3.508.. Valid. accuracy: 0.287
# Step 35/205..  Epoch 1/5.. Train loss: 3.809.. Valid. loss: 3.388.. Valid. accuracy: 0.292
# Step 40/205..  Epoch 1/5.. Train loss: 3.464.. Valid. loss: 3.352.. Valid. accuracy: 0.309
# Step 45/205..  Epoch 1/5.. Train loss: 3.798.. Valid. loss: 3.105.. Valid. accuracy: 0.277
# Step 50/205..  Epoch 1/5.. Train loss: 3.324.. Valid. loss: 2.996.. Valid. accuracy: 0.331
# Step 55/205..  Epoch 1/5.. Train loss: 3.619.. Valid. loss: 2.852.. Valid. accuracy: 0.347
# Step 60/205..  Epoch 1/5.. Train loss: 3.080.. Valid. loss: 2.622.. Valid. accuracy: 0.396
# Step 65/205..  Epoch 1/5.. Train loss: 3.043.. Valid. loss: 2.483.. Valid. accuracy: 0.415
# Step 70/205..  Epoch 1/5.. Train loss: 3.098.. Valid. loss: 2.286.. Valid. accuracy: 0.436
# Step 75/205..  Epoch 1/5.. Train loss: 3.125.. Valid. loss: 2.366.. Valid. accuracy: 0.422
# Step 80/205..  Epoch 1/5.. Train loss: 2.690.. Valid. loss: 2.442.. Valid. accuracy: 0.399
# Step 85/205..  Epoch 1/5.. Train loss: 3.025.. Valid. loss: 2.427.. Valid. accuracy: 0.396
# Step 90/205..  Epoch 1/5.. Train loss: 2.801.. Valid. loss: 2.473.. Valid. accuracy: 0.388
# Step 95/205..  Epoch 1/5.. Train loss: 2.543.. Valid. loss: 2.106.. Valid. accuracy: 0.467
# Step 100/205..  Epoch 1/5.. Train loss: 2.886.. Valid. loss: 2.014.. Valid. accuracy: 0.501
# Step 105/205..  Epoch 1/5.. Train loss: 2.733.. Valid. loss: 2.107.. Valid. accuracy: 0.456
# Step 110/205..  Epoch 1/5.. Train loss: 2.713.. Valid. loss: 2.105.. Valid. accuracy: 0.444
# Step 115/205..  Epoch 1/5.. Train loss: 2.777.. Valid. loss: 1.893.. Valid. accuracy: 0.507
# Step 120/205..  Epoch 1/5.. Train loss: 2.541.. Valid. loss: 1.789.. Valid. accuracy: 0.538
# Step 125/205..  Epoch 1/5.. Train loss: 2.213.. Valid. loss: 1.784.. Valid. accuracy: 0.553
# Step 130/205..  Epoch 1/5.. Train loss: 2.650.. Valid. loss: 1.799.. Valid. accuracy: 0.543
# Step 135/205..  Epoch 1/5.. Train loss: 2.552.. Valid. loss: 1.829.. Valid. accuracy: 0.543
# Step 140/205..  Epoch 1/5.. Train loss: 2.681.. Valid. loss: 1.880.. Valid. accuracy: 0.521
# Step 145/205..  Epoch 1/5.. Train loss: 2.530.. Valid. loss: 1.743.. Valid. accuracy: 0.532
# Step 150/205..  Epoch 1/5.. Train loss: 2.315.. Valid. loss: 1.740.. Valid. accuracy: 0.511
# Step 155/205..  Epoch 1/5.. Train loss: 2.357.. Valid. loss: 1.833.. Valid. accuracy: 0.514
# Step 160/205..  Epoch 1/5.. Train loss: 2.482.. Valid. loss: 1.929.. Valid. accuracy: 0.488
# Step 165/205..  Epoch 1/5.. Train loss: 2.627.. Valid. loss: 1.731.. Valid. accuracy: 0.534
# Step 170/205..  Epoch 1/5.. Train loss: 2.568.. Valid. loss: 1.680.. Valid. accuracy: 0.557
# Step 175/205..  Epoch 1/5.. Train loss: 2.571.. Valid. loss: 1.788.. Valid. accuracy: 0.567
# Step 180/205..  Epoch 1/5.. Train loss: 2.300.. Valid. loss: 1.865.. Valid. accuracy: 0.535
# Step 185/205..  Epoch 1/5.. Train loss: 2.325.. Valid. loss: 1.861.. Valid. accuracy: 0.547
# Step 190/205..  Epoch 1/5.. Train loss: 2.439.. Valid. loss: 1.819.. Valid. accuracy: 0.526
# Step 195/205..  Epoch 1/5.. Train loss: 2.514.. Valid. loss: 1.669.. Valid. accuracy: 0.554
# Step 200/205..  Epoch 1/5.. Train loss: 2.263.. Valid. loss: 1.662.. Valid. accuracy: 0.577
# Step 205/205..  Epoch 1/5.. Train loss: 2.130.. Valid. loss: 1.622.. Valid. accuracy: 0.573
# 3.6.6 |Anaconda, Inc.| (default, Jun 28 2018, 11:27:44) [MSC v.1900 64 bit (AMD64)]
# 19.7
# svmem(total=16978071552, available=8266268672, percent=51.3, used=8711802880, free=8266268672)
# memory GB: 1.8522491455078125
# <class 'torch.Tensor'> torch.Size([4096, 25088])
# <class 'torch.Tensor'> torch.Size([4096, 25088])
# <class 'torch.Tensor'> torch.Size([4096])
# <class 'torch.Tensor'> torch.Size([4096])
# <class 'torch.Tensor'> torch.Size([102, 4096])
# <class 'torch.Tensor'> torch.Size([102, 4096])
# <class 'torch.Tensor'> torch.Size([102])
# <class 'torch.Tensor'> torch.Size([102])
# <class 'torch.Tensor'> torch.Size([24, 3, 224, 224])
# <class 'torch.Tensor'> torch.Size([24])
# <class 'torch.Tensor'> torch.Size([24, 102])
# <class 'torch.Tensor'> torch.Size([])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64, 3, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64, 64, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128, 64, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128, 128, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 128, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 256, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1000])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 256, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 256, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([102])
# <class 'torch.nn.parameter.Parameter'> torch.Size([102, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 25088])
# Step 5/205..  Epoch 2/5.. Train loss: 1.970.. Valid. loss: 1.627.. Valid. accuracy: 0.588
# Step 10/205..  Epoch 2/5.. Train loss: 2.282.. Valid. loss: 1.728.. Valid. accuracy: 0.568
# Step 15/205..  Epoch 2/5.. Train loss: 2.369.. Valid. loss: 1.665.. Valid. accuracy: 0.588
# Step 20/205..  Epoch 2/5.. Train loss: 2.135.. Valid. loss: 1.671.. Valid. accuracy: 0.542
# Step 25/205..  Epoch 2/5.. Train loss: 2.497.. Valid. loss: 1.476.. Valid. accuracy: 0.605
# Step 30/205..  Epoch 2/5.. Train loss: 2.020.. Valid. loss: 1.591.. Valid. accuracy: 0.578
# Step 35/205..  Epoch 2/5.. Train loss: 2.423.. Valid. loss: 1.693.. Valid. accuracy: 0.566
# Step 40/205..  Epoch 2/5.. Train loss: 2.359.. Valid. loss: 1.646.. Valid. accuracy: 0.567
# Step 45/205..  Epoch 2/5.. Train loss: 2.386.. Valid. loss: 1.631.. Valid. accuracy: 0.556
# Step 50/205..  Epoch 2/5.. Train loss: 1.986.. Valid. loss: 1.628.. Valid. accuracy: 0.564
# Step 55/205..  Epoch 2/5.. Train loss: 2.483.. Valid. loss: 1.477.. Valid. accuracy: 0.601
# Step 60/205..  Epoch 2/5.. Train loss: 2.429.. Valid. loss: 1.528.. Valid. accuracy: 0.596
# Step 65/205..  Epoch 2/5.. Train loss: 2.146.. Valid. loss: 1.548.. Valid. accuracy: 0.594
# Step 70/205..  Epoch 2/5.. Train loss: 1.885.. Valid. loss: 1.495.. Valid. accuracy: 0.609
# Step 75/205..  Epoch 2/5.. Train loss: 1.868.. Valid. loss: 1.454.. Valid. accuracy: 0.633
# Step 80/205..  Epoch 2/5.. Train loss: 2.406.. Valid. loss: 1.485.. Valid. accuracy: 0.614
# Step 85/205..  Epoch 2/5.. Train loss: 2.077.. Valid. loss: 1.495.. Valid. accuracy: 0.623
# Step 90/205..  Epoch 2/5.. Train loss: 2.332.. Valid. loss: 1.507.. Valid. accuracy: 0.616
# Step 95/205..  Epoch 2/5.. Train loss: 2.077.. Valid. loss: 1.519.. Valid. accuracy: 0.603
# Step 100/205..  Epoch 2/5.. Train loss: 2.099.. Valid. loss: 1.485.. Valid. accuracy: 0.625
# Step 105/205..  Epoch 2/5.. Train loss: 2.217.. Valid. loss: 1.547.. Valid. accuracy: 0.636
# Step 110/205..  Epoch 2/5.. Train loss: 2.020.. Valid. loss: 1.470.. Valid. accuracy: 0.653
# Step 115/205..  Epoch 2/5.. Train loss: 2.257.. Valid. loss: 1.480.. Valid. accuracy: 0.626
# Step 120/205..  Epoch 2/5.. Train loss: 1.829.. Valid. loss: 1.409.. Valid. accuracy: 0.643
# Step 125/205..  Epoch 2/5.. Train loss: 2.356.. Valid. loss: 1.364.. Valid. accuracy: 0.663
# Step 130/205..  Epoch 2/5.. Train loss: 2.219.. Valid. loss: 1.394.. Valid. accuracy: 0.632
# Step 135/205..  Epoch 2/5.. Train loss: 2.169.. Valid. loss: 1.626.. Valid. accuracy: 0.582
# Step 140/205..  Epoch 2/5.. Train loss: 2.241.. Valid. loss: 1.502.. Valid. accuracy: 0.623
# Step 145/205..  Epoch 2/5.. Train loss: 2.366.. Valid. loss: 1.610.. Valid. accuracy: 0.598
# Step 150/205..  Epoch 2/5.. Train loss: 2.256.. Valid. loss: 1.483.. Valid. accuracy: 0.621
# Step 155/205..  Epoch 2/5.. Train loss: 2.262.. Valid. loss: 1.406.. Valid. accuracy: 0.634
# Step 160/205..  Epoch 2/5.. Train loss: 2.157.. Valid. loss: 1.416.. Valid. accuracy: 0.650
# Step 165/205..  Epoch 2/5.. Train loss: 1.974.. Valid. loss: 1.315.. Valid. accuracy: 0.662
# Step 170/205..  Epoch 2/5.. Train loss: 2.001.. Valid. loss: 1.393.. Valid. accuracy: 0.628
# Step 175/205..  Epoch 2/5.. Train loss: 2.294.. Valid. loss: 1.269.. Valid. accuracy: 0.648
# Step 180/205..  Epoch 2/5.. Train loss: 2.159.. Valid. loss: 1.258.. Valid. accuracy: 0.665
# Step 185/205..  Epoch 2/5.. Train loss: 2.574.. Valid. loss: 1.266.. Valid. accuracy: 0.646
# Step 190/205..  Epoch 2/5.. Train loss: 2.261.. Valid. loss: 1.400.. Valid. accuracy: 0.637
# Step 195/205..  Epoch 2/5.. Train loss: 1.924.. Valid. loss: 1.445.. Valid. accuracy: 0.621
# Step 200/205..  Epoch 2/5.. Train loss: 2.682.. Valid. loss: 1.384.. Valid. accuracy: 0.636
# Step 205/205..  Epoch 2/5.. Train loss: 1.715.. Valid. loss: 1.405.. Valid. accuracy: 0.636
# 3.6.6 |Anaconda, Inc.| (default, Jun 28 2018, 11:27:44) [MSC v.1900 64 bit (AMD64)]
# 19.2
# svmem(total=16978071552, available=8482512896, percent=50.0, used=8495558656, free=8482512896)
# memory GB: 1.8095474243164062
# <class 'torch.Tensor'> torch.Size([4096, 25088])
# <class 'torch.Tensor'> torch.Size([4096, 25088])
# <class 'torch.Tensor'> torch.Size([4096])
# <class 'torch.Tensor'> torch.Size([4096])
# <class 'torch.Tensor'> torch.Size([102, 4096])
# <class 'torch.Tensor'> torch.Size([102, 4096])
# <class 'torch.Tensor'> torch.Size([102])
# <class 'torch.Tensor'> torch.Size([102])
# <class 'torch.Tensor'> torch.Size([24, 3, 224, 224])
# <class 'torch.Tensor'> torch.Size([24])
# <class 'torch.Tensor'> torch.Size([24, 102])
# <class 'torch.Tensor'> torch.Size([])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64, 3, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64, 64, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128, 64, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128, 128, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 128, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 256, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1000])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 256, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 256, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([102])
# <class 'torch.nn.parameter.Parameter'> torch.Size([102, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 25088])
# Step 5/205..  Epoch 3/5.. Train loss: 1.958.. Valid. loss: 1.464.. Valid. accuracy: 0.626
# Step 10/205..  Epoch 3/5.. Train loss: 2.427.. Valid. loss: 1.287.. Valid. accuracy: 0.667
# Step 15/205..  Epoch 3/5.. Train loss: 1.866.. Valid. loss: 1.238.. Valid. accuracy: 0.680
# Step 20/205..  Epoch 3/5.. Train loss: 2.402.. Valid. loss: 1.316.. Valid. accuracy: 0.665
# Step 25/205..  Epoch 3/5.. Train loss: 1.955.. Valid. loss: 1.339.. Valid. accuracy: 0.659
# Step 30/205..  Epoch 3/5.. Train loss: 1.872.. Valid. loss: 1.416.. Valid. accuracy: 0.666
# Step 35/205..  Epoch 3/5.. Train loss: 1.866.. Valid. loss: 1.406.. Valid. accuracy: 0.650
# Step 40/205..  Epoch 3/5.. Train loss: 1.978.. Valid. loss: 1.304.. Valid. accuracy: 0.655
# Step 45/205..  Epoch 3/5.. Train loss: 2.022.. Valid. loss: 1.334.. Valid. accuracy: 0.653
# Step 50/205..  Epoch 3/5.. Train loss: 2.014.. Valid. loss: 1.310.. Valid. accuracy: 0.680
# Step 55/205..  Epoch 3/5.. Train loss: 2.103.. Valid. loss: 1.356.. Valid. accuracy: 0.662
# Step 60/205..  Epoch 3/5.. Train loss: 2.304.. Valid. loss: 1.358.. Valid. accuracy: 0.647
# Step 65/205..  Epoch 3/5.. Train loss: 2.405.. Valid. loss: 1.314.. Valid. accuracy: 0.658
# Step 70/205..  Epoch 3/5.. Train loss: 1.732.. Valid. loss: 1.306.. Valid. accuracy: 0.648
# Step 75/205..  Epoch 3/5.. Train loss: 1.664.. Valid. loss: 1.306.. Valid. accuracy: 0.661
# Step 80/205..  Epoch 3/5.. Train loss: 2.025.. Valid. loss: 1.273.. Valid. accuracy: 0.687
# Step 85/205..  Epoch 3/5.. Train loss: 1.798.. Valid. loss: 1.271.. Valid. accuracy: 0.682
# Step 90/205..  Epoch 3/5.. Train loss: 2.005.. Valid. loss: 1.233.. Valid. accuracy: 0.678
# Step 95/205..  Epoch 3/5.. Train loss: 2.148.. Valid. loss: 1.185.. Valid. accuracy: 0.682
# Step 100/205..  Epoch 3/5.. Train loss: 1.993.. Valid. loss: 1.151.. Valid. accuracy: 0.692
# Step 105/205..  Epoch 3/5.. Train loss: 2.038.. Valid. loss: 1.186.. Valid. accuracy: 0.697
# Step 110/205..  Epoch 3/5.. Train loss: 1.654.. Valid. loss: 1.362.. Valid. accuracy: 0.678
# Step 115/205..  Epoch 3/5.. Train loss: 1.909.. Valid. loss: 1.369.. Valid. accuracy: 0.678
# Step 120/205..  Epoch 3/5.. Train loss: 1.901.. Valid. loss: 1.244.. Valid. accuracy: 0.702
# Step 125/205..  Epoch 3/5.. Train loss: 1.798.. Valid. loss: 1.245.. Valid. accuracy: 0.697
# Step 130/205..  Epoch 3/5.. Train loss: 1.694.. Valid. loss: 1.269.. Valid. accuracy: 0.695
# Step 135/205..  Epoch 3/5.. Train loss: 1.705.. Valid. loss: 1.320.. Valid. accuracy: 0.686
# Step 140/205..  Epoch 3/5.. Train loss: 1.784.. Valid. loss: 1.367.. Valid. accuracy: 0.690
# Step 145/205..  Epoch 3/5.. Train loss: 1.867.. Valid. loss: 1.315.. Valid. accuracy: 0.676
# Step 150/205..  Epoch 3/5.. Train loss: 1.693.. Valid. loss: 1.243.. Valid. accuracy: 0.683
# Step 155/205..  Epoch 3/5.. Train loss: 2.312.. Valid. loss: 1.214.. Valid. accuracy: 0.690
# Step 160/205..  Epoch 3/5.. Train loss: 1.923.. Valid. loss: 1.254.. Valid. accuracy: 0.682
# Step 165/205..  Epoch 3/5.. Train loss: 2.245.. Valid. loss: 1.298.. Valid. accuracy: 0.686
# Step 170/205..  Epoch 3/5.. Train loss: 2.067.. Valid. loss: 1.238.. Valid. accuracy: 0.699
# Step 175/205..  Epoch 3/5.. Train loss: 1.684.. Valid. loss: 1.251.. Valid. accuracy: 0.695
# Step 180/205..  Epoch 3/5.. Train loss: 1.894.. Valid. loss: 1.172.. Valid. accuracy: 0.707
# Step 185/205..  Epoch 3/5.. Train loss: 1.705.. Valid. loss: 1.173.. Valid. accuracy: 0.707
# Step 190/205..  Epoch 3/5.. Train loss: 1.711.. Valid. loss: 1.172.. Valid. accuracy: 0.706
# Step 195/205..  Epoch 3/5.. Train loss: 1.948.. Valid. loss: 1.188.. Valid. accuracy: 0.691
# Step 200/205..  Epoch 3/5.. Train loss: 2.212.. Valid. loss: 1.136.. Valid. accuracy: 0.718
# Step 205/205..  Epoch 3/5.. Train loss: 2.091.. Valid. loss: 1.106.. Valid. accuracy: 0.721
# 3.6.6 |Anaconda, Inc.| (default, Jun 28 2018, 11:27:44) [MSC v.1900 64 bit (AMD64)]
# 19.0
# svmem(total=16978071552, available=8604594176, percent=49.3, used=8373477376, free=8604594176)
# memory GB: 1.8095321655273438
# <class 'torch.Tensor'> torch.Size([4096, 25088])
# <class 'torch.Tensor'> torch.Size([4096, 25088])
# <class 'torch.Tensor'> torch.Size([4096])
# <class 'torch.Tensor'> torch.Size([4096])
# <class 'torch.Tensor'> torch.Size([102, 4096])
# <class 'torch.Tensor'> torch.Size([102, 4096])
# <class 'torch.Tensor'> torch.Size([102])
# <class 'torch.Tensor'> torch.Size([102])
# <class 'torch.Tensor'> torch.Size([24, 3, 224, 224])
# <class 'torch.Tensor'> torch.Size([24])
# <class 'torch.Tensor'> torch.Size([24, 102])
# <class 'torch.Tensor'> torch.Size([])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64, 3, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64, 64, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128, 64, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128, 128, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 128, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 256, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1000])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 256, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 256, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([102])
# <class 'torch.nn.parameter.Parameter'> torch.Size([102, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 25088])
# Step 5/205..  Epoch 4/5.. Train loss: 1.664.. Valid. loss: 1.152.. Valid. accuracy: 0.718
# Step 10/205..  Epoch 4/5.. Train loss: 1.467.. Valid. loss: 1.319.. Valid. accuracy: 0.706
# Step 15/205..  Epoch 4/5.. Train loss: 2.046.. Valid. loss: 1.304.. Valid. accuracy: 0.689
# Step 20/205..  Epoch 4/5.. Train loss: 2.012.. Valid. loss: 1.206.. Valid. accuracy: 0.699
# Step 25/205..  Epoch 4/5.. Train loss: 1.686.. Valid. loss: 1.303.. Valid. accuracy: 0.671
# Step 30/205..  Epoch 4/5.. Train loss: 1.859.. Valid. loss: 1.322.. Valid. accuracy: 0.672
# Step 35/205..  Epoch 4/5.. Train loss: 1.697.. Valid. loss: 1.273.. Valid. accuracy: 0.670
# Step 40/205..  Epoch 4/5.. Train loss: 2.041.. Valid. loss: 1.392.. Valid. accuracy: 0.660
# Step 45/205..  Epoch 4/5.. Train loss: 1.793.. Valid. loss: 1.271.. Valid. accuracy: 0.704
# Step 50/205..  Epoch 4/5.. Train loss: 2.023.. Valid. loss: 1.346.. Valid. accuracy: 0.686
# Step 55/205..  Epoch 4/5.. Train loss: 1.929.. Valid. loss: 1.297.. Valid. accuracy: 0.681
# Step 60/205..  Epoch 4/5.. Train loss: 2.096.. Valid. loss: 1.327.. Valid. accuracy: 0.669
# Step 65/205..  Epoch 4/5.. Train loss: 1.663.. Valid. loss: 1.316.. Valid. accuracy: 0.678
# Step 70/205..  Epoch 4/5.. Train loss: 1.700.. Valid. loss: 1.280.. Valid. accuracy: 0.690
# Step 75/205..  Epoch 4/5.. Train loss: 1.750.. Valid. loss: 1.228.. Valid. accuracy: 0.704
# Step 80/205..  Epoch 4/5.. Train loss: 1.759.. Valid. loss: 1.296.. Valid. accuracy: 0.690
# Step 85/205..  Epoch 4/5.. Train loss: 2.111.. Valid. loss: 1.433.. Valid. accuracy: 0.668
# Step 90/205..  Epoch 4/5.. Train loss: 2.027.. Valid. loss: 1.286.. Valid. accuracy: 0.702
# Step 95/205..  Epoch 4/5.. Train loss: 1.695.. Valid. loss: 1.251.. Valid. accuracy: 0.682
# Step 100/205..  Epoch 4/5.. Train loss: 1.858.. Valid. loss: 1.245.. Valid. accuracy: 0.694
# Step 105/205..  Epoch 4/5.. Train loss: 1.738.. Valid. loss: 1.109.. Valid. accuracy: 0.721
# Step 110/205..  Epoch 4/5.. Train loss: 1.820.. Valid. loss: 1.091.. Valid. accuracy: 0.719
# Step 115/205..  Epoch 4/5.. Train loss: 1.448.. Valid. loss: 1.194.. Valid. accuracy: 0.724
# Step 120/205..  Epoch 4/5.. Train loss: 1.773.. Valid. loss: 1.309.. Valid. accuracy: 0.703
# Step 125/205..  Epoch 4/5.. Train loss: 2.117.. Valid. loss: 1.331.. Valid. accuracy: 0.689
# Step 130/205..  Epoch 4/5.. Train loss: 1.906.. Valid. loss: 1.356.. Valid. accuracy: 0.675
# Step 135/205..  Epoch 4/5.. Train loss: 1.917.. Valid. loss: 1.325.. Valid. accuracy: 0.687
# Step 140/205..  Epoch 4/5.. Train loss: 1.689.. Valid. loss: 1.323.. Valid. accuracy: 0.669
# Step 145/205..  Epoch 4/5.. Train loss: 2.005.. Valid. loss: 1.297.. Valid. accuracy: 0.669
# Step 150/205..  Epoch 4/5.. Train loss: 1.838.. Valid. loss: 1.259.. Valid. accuracy: 0.677
# Step 155/205..  Epoch 4/5.. Train loss: 2.030.. Valid. loss: 1.226.. Valid. accuracy: 0.672
# Step 160/205..  Epoch 4/5.. Train loss: 1.603.. Valid. loss: 1.224.. Valid. accuracy: 0.684
# Step 165/205..  Epoch 4/5.. Train loss: 1.737.. Valid. loss: 1.286.. Valid. accuracy: 0.694
# Step 170/205..  Epoch 4/5.. Train loss: 2.021.. Valid. loss: 1.311.. Valid. accuracy: 0.685
# Step 175/205..  Epoch 4/5.. Train loss: 1.826.. Valid. loss: 1.217.. Valid. accuracy: 0.707
# Step 180/205..  Epoch 4/5.. Train loss: 1.785.. Valid. loss: 1.238.. Valid. accuracy: 0.703
# Step 185/205..  Epoch 4/5.. Train loss: 1.738.. Valid. loss: 1.284.. Valid. accuracy: 0.703
# Step 190/205..  Epoch 4/5.. Train loss: 2.092.. Valid. loss: 1.285.. Valid. accuracy: 0.687
# Step 195/205..  Epoch 4/5.. Train loss: 1.891.. Valid. loss: 1.194.. Valid. accuracy: 0.701
# Step 200/205..  Epoch 4/5.. Train loss: 1.607.. Valid. loss: 1.218.. Valid. accuracy: 0.705
# Step 205/205..  Epoch 4/5.. Train loss: 1.718.. Valid. loss: 1.306.. Valid. accuracy: 0.690
# 3.6.6 |Anaconda, Inc.| (default, Jun 28 2018, 11:27:44) [MSC v.1900 64 bit (AMD64)]
# 19.0
# svmem(total=16978071552, available=8585154560, percent=49.4, used=8392916992, free=8585154560)
# memory GB: 1.8095245361328125
# <class 'torch.Tensor'> torch.Size([4096, 25088])
# <class 'torch.Tensor'> torch.Size([4096, 25088])
# <class 'torch.Tensor'> torch.Size([4096])
# <class 'torch.Tensor'> torch.Size([4096])
# <class 'torch.Tensor'> torch.Size([102, 4096])
# <class 'torch.Tensor'> torch.Size([102, 4096])
# <class 'torch.Tensor'> torch.Size([102])
# <class 'torch.Tensor'> torch.Size([102])
# <class 'torch.Tensor'> torch.Size([24, 3, 224, 224])
# <class 'torch.Tensor'> torch.Size([24])
# <class 'torch.Tensor'> torch.Size([24, 102])
# <class 'torch.Tensor'> torch.Size([])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64, 3, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64, 64, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([64])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128, 64, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128, 128, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([128])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 128, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 256, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([1000])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256, 256, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([256])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 256, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512, 512, 3, 3])
# <class 'torch.nn.parameter.Parameter'> torch.Size([512])
# <class 'torch.nn.parameter.Parameter'> torch.Size([102])
# <class 'torch.nn.parameter.Parameter'> torch.Size([102, 4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096])
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 25088])
# Step 5/205..  Epoch 5/5.. Train loss: 1.623.. Valid. loss: 1.210.. Valid. accuracy: 0.717
# Step 10/205..  Epoch 5/5.. Train loss: 1.982.. Valid. loss: 1.157.. Valid. accuracy: 0.733
# Step 15/205..  Epoch 5/5.. Train loss: 1.965.. Valid. loss: 1.190.. Valid. accuracy: 0.723
# Step 20/205..  Epoch 5/5.. Train loss: 1.663.. Valid. loss: 1.150.. Valid. accuracy: 0.726
# Step 25/205..  Epoch 5/5.. Train loss: 1.960.. Valid. loss: 1.217.. Valid. accuracy: 0.710
# Step 30/205..  Epoch 5/5.. Train loss: 1.767.. Valid. loss: 1.332.. Valid. accuracy: 0.670
# Step 35/205..  Epoch 5/5.. Train loss: 1.711.. Valid. loss: 1.308.. Valid. accuracy: 0.675
# Step 40/205..  Epoch 5/5.. Train loss: 1.596.. Valid. loss: 1.217.. Valid. accuracy: 0.693
# Step 45/205..  Epoch 5/5.. Train loss: 1.712.. Valid. loss: 1.372.. Valid. accuracy: 0.676
# Step 50/205..  Epoch 5/5.. Train loss: 1.856.. Valid. loss: 1.191.. Valid. accuracy: 0.709
# Step 55/205..  Epoch 5/5.. Train loss: 1.580.. Valid. loss: 1.209.. Valid. accuracy: 0.708
# Step 60/205..  Epoch 5/5.. Train loss: 1.753.. Valid. loss: 1.218.. Valid. accuracy: 0.709
# Step 65/205..  Epoch 5/5.. Train loss: 1.323.. Valid. loss: 1.172.. Valid. accuracy: 0.706
# Step 70/205..  Epoch 5/5.. Train loss: 2.193.. Valid. loss: 1.174.. Valid. accuracy: 0.717
# Step 75/205..  Epoch 5/5.. Train loss: 1.882.. Valid. loss: 1.101.. Valid. accuracy: 0.730
# Step 80/205..  Epoch 5/5.. Train loss: 1.774.. Valid. loss: 1.103.. Valid. accuracy: 0.720
# Step 85/205..  Epoch 5/5.. Train loss: 1.715.. Valid. loss: 1.127.. Valid. accuracy: 0.716
# Step 90/205..  Epoch 5/5.. Train loss: 1.865.. Valid. loss: 1.173.. Valid. accuracy: 0.712
# Step 95/205..  Epoch 5/5.. Train loss: 1.754.. Valid. loss: 1.227.. Valid. accuracy: 0.715
# Step 100/205..  Epoch 5/5.. Train loss: 1.721.. Valid. loss: 1.250.. Valid. accuracy: 0.714
# Step 105/205..  Epoch 5/5.. Train loss: 2.013.. Valid. loss: 1.308.. Valid. accuracy: 0.678
# Step 110/205..  Epoch 5/5.. Train loss: 2.012.. Valid. loss: 1.302.. Valid. accuracy: 0.699
# Step 115/205..  Epoch 5/5.. Train loss: 1.872.. Valid. loss: 1.277.. Valid. accuracy: 0.695
# Step 120/205..  Epoch 5/5.. Train loss: 1.964.. Valid. loss: 1.284.. Valid. accuracy: 0.674
# Step 125/205..  Epoch 5/5.. Train loss: 1.995.. Valid. loss: 1.219.. Valid. accuracy: 0.689
# Step 130/205..  Epoch 5/5.. Train loss: 2.177.. Valid. loss: 1.230.. Valid. accuracy: 0.698
# Step 135/205..  Epoch 5/5.. Train loss: 2.056.. Valid. loss: 1.266.. Valid. accuracy: 0.690
# Step 140/205..  Epoch 5/5.. Train loss: 1.796.. Valid. loss: 1.259.. Valid. accuracy: 0.686
# Step 145/205..  Epoch 5/5.. Train loss: 1.771.. Valid. loss: 1.189.. Valid. accuracy: 0.703
# Step 150/205..  Epoch 5/5.. Train loss: 1.519.. Valid. loss: 1.185.. Valid. accuracy: 0.711
# Step 155/205..  Epoch 5/5.. Train loss: 2.024.. Valid. loss: 1.172.. Valid. accuracy: 0.722
# Step 160/205..  Epoch 5/5.. Train loss: 1.693.. Valid. loss: 1.148.. Valid. accuracy: 0.706
# Step 165/205..  Epoch 5/5.. Train loss: 1.591.. Valid. loss: 1.260.. Valid. accuracy: 0.699
# Step 170/205..  Epoch 5/5.. Train loss: 1.924.. Valid. loss: 1.265.. Valid. accuracy: 0.695
# Step 175/205..  Epoch 5/5.. Train loss: 1.913.. Valid. loss: 1.234.. Valid. accuracy: 0.711
# Step 180/205..  Epoch 5/5.. Train loss: 2.081.. Valid. loss: 1.414.. Valid. accuracy: 0.696
# Step 185/205..  Epoch 5/5.. Train loss: 1.729.. Valid. loss: 1.193.. Valid. accuracy: 0.734
# Step 190/205..  Epoch 5/5.. Train loss: 1.945.. Valid. loss: 1.235.. Valid. accuracy: 0.717
# Step 195/205..  Epoch 5/5.. Train loss: 2.125.. Valid. loss: 1.139.. Valid. accuracy: 0.710
# Step 200/205..  Epoch 5/5.. Train loss: 1.641.. Valid. loss: 1.125.. Valid. accuracy: 0.728
# Step 205/205..  Epoch 5/5.. Train loss: 1.928.. Valid. loss: 1.101.. Valid. accuracy: 0.719

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# Do validation on the test set

loss, accuracy = validate_nn(testloader, model)
print(f"Test loss: {loss/len(testloader):.3f}, "
      f"Test accuracy: {accuracy/len(testloader):.3f}")
# Out:
# Test loss: 1.358, Test accuracy: 0.671

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
checkpoint = {'epoch': epochs,
              'n_classes': num_classes,
              'name': model.name,
              'classifier' : classifier_dict,
              'state_dict': model.state_dict(),
             }

torch.save(checkpoint, 'checkpoint.pth')

# %%
print(epochs)
print(num_classes)
print(model.name)
print(classifier_dict)
#print(optimizer.state_dict())
#print(model.state_dict())
# Out:
# 5
# 102
# vgg16
# OrderedDict([('fc1', Linear(in_features=25088, out_features=4096, bias=True)), ('relu', ReLU()), ('do1', Dropout(p=0.1)), ('fc2', Linear(in_features=4096, out_features=102, bias=True)), ('output', LogSoftmax())])

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_checkpoint(filepath):
    checkpoint = torch.load(filepath)
    model = models.vgg16(pretrained=True)
    
    # Freeze parameters so we don't backprop through them
    for param in model.parameters():
        param.requires_grad = False

    classifier_dict = checkpoint['classifier']
    model.classifier = nn.Sequential(classifier_dict)
    model.load_state_dict(checkpoint['state_dict'])    
    del(checkpoint)
    
    return model


model_t = load_checkpoint('checkpoint.pth')
#model_t
# load model into gpu
model_t.to(device = torch.device('cuda'));

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
from PIL import Image
import numpy as np
import torch
def process_image(img, convert=True):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    if convert:
        new_width = 224    
        new_height = 224
        width, height = img.size
        ratio = float(width)/float(height)        
        if width > height:
            width = int(256.0 * ratio)
            height = 256
        else:
            ratio = 1.0/ratio
            height = int(256 * ratio)
            width = 256


        print('{} {} {}'.format(width, height, ratio))
        #img.resize((int(width), int(height)), Image.ANTIALIAS)
        img.thumbnail((width, height), Image.NEAREST)
        left = (width - new_width)/2
        right = (width + new_width)/2
        top = (height - new_height)/2
        bottom = (height + new_height)/2
        print('{} {} {} {}'.format(left, top, right, bottom))

        img = img.crop((left, top, right, bottom))        

    np_image = np.array(img)
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    
    image_flt = np_image/255
    norm_image = (image_flt - mean)/std
    
    trans_image = norm_image.transpose((2,0,1))
    
    return torch.tensor(trans_image, device='cuda:0')
        
fname = 'flowers/test/1/image_06743.jpg'    
img = Image.open(fname)
orig = process_image(img, False)  
image = process_image(img)
print(orig.shape)
print(image.shape)
print(image.dtype)
# Out:
# 256 307 1.202
# 16.0 41.5 240.0 265.5
# torch.Size([3, 601, 500])
# torch.Size([3, 224, 224])
# torch.float64

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
from matplotlib import pyplot as plt
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.cpu().numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %%
imshow(orig)

# %%
imshow(image)

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''    
    # TODO: Implement the code to predict the class from an image file
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    #device = torch.device('cuda')
    image = Image.open(image_path)
    pimage = process_image(image)
    inputs = pimage
    inputs = inputs.to(device)
    model.eval()
    with torch.no_grad():
        print(pimage[None].shape)
        logps = model.forward(pimage[None].float())
        ps = torch.exp(logps)
        top_p, top_class = ps.topk(5, dim=1)
        probs = [float(p) for p in top_p[0]]
        classes = [cat_to_name[idx_to_class[int(i)]] for i in top_class[0]]
        
        return probs, classes

# %%
probs, classes = predict(fname, model_t)
print(probs)
print(classes)
# Out:
# 256 307 1.202
# 16.0 41.5 240.0 265.5
# torch.Size([1, 3, 224, 224])
# [0.3109661936759949, 0.3107341229915619, 0.22097568213939667, 0.04506264254450798, 0.02609548158943653]
# ['petunia', 'hibiscus', 'pink primrose', 'hippeastrum', 'morning glory']

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
